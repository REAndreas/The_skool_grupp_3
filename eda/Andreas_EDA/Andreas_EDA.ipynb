# %% [markdown]
# # EDA Yrkeshögskolan

# %%
import pandas as pd

df = pd.read_csv("data/Yrkeshogskolan.csv", encoding="ISO-8859-1")

df.head()
# Out:
#       kön                 utbildningens inriktning   ålder  2020  2021  2022  \
# 0  totalt                                  Data/It  totalt  5647  5387  5831
# 1  totalt  Ekonomi, administration och försäljning  totalt  7991  6522  6602
# 2  totalt                 Friskvård och kroppsvård  totalt   167   180   210
# 3  totalt            Hotell, restaurang och turism  totalt  1479  1369  1069
# 4  totalt  Hälso- och sjukvård samt socialt arbete  totalt  5221  5343  5415
#
#    2023  2024
# 0  6445  6490
# 1  7034  6531
# 2   230   122
# 3  1155  1251
# 4  5076  4761

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   kön                       15 non-null     object
#  1   utbildningens inriktning  15 non-null     object
#  2   ålder                     15 non-null     object
#  3   2020                      15 non-null     int64
#  4   2021                      15 non-null     int64
#  5   2022                      15 non-null     int64
#  6   2023                      15 non-null     int64
#  7   2024                      15 non-null     int64
# dtypes: int64(5), object(3)
# memory usage: 1.1+ KB

# %%
df = df.drop(labels="kön", axis=1)

df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df = df.drop(labels="kön", axis=1)
#       2 df= df.drop(labels="ålder", axis=1)
#       4 df
#
# File c:\Users\Andre\Documents\Github\The_skool_grupp_3\.venv\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)   5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)   5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
# ...

# %%
df= df.drop(labels="ålder", axis=1)

df
# Out:
#                         utbildningens inriktning  2020  2021  2022  2023  2024
# 0                                        Data/It  5647  5387  5831  6445  6490
# 1        Ekonomi, administration och försäljning  7991  6522  6602  7034  6531
# 2                       Friskvård och kroppsvård   167   180   210   230   122
# 3                  Hotell, restaurang och turism  1479  1369  1069  1155  1251
# 4        Hälso- och sjukvård samt socialt arbete  5221  5343  5415  5076  4761
# 5                   Journalistik och information   369   351   293   283   232
# 6                                        Juridik   209   178   141   144   135
# 7                       Kultur, media och design  1505  1547  1569  1770  1660
# 8   Lantbruk, djurvård, trädgård, skog och fiske   677   806   816   931  1019
# 9                     Pedagogik och undervisning   889   878   883   488   414
# 10                Samhällsbyggnad och byggteknik  5636  4787  4815  5090  5518
# ...

# %%
df.head()
# Out:
#                   utbildningens inriktning  2020  2021  2022  2023  2024
# 0                                  Data/It  5647  5387  5831  6445  6490
# 1  Ekonomi, administration och försäljning  7991  6522  6602  7034  6531
# 2                 Friskvård och kroppsvård   167   180   210   230   122
# 3            Hotell, restaurang och turism  1479  1369  1069  1155  1251
# 4  Hälso- och sjukvård samt socialt arbete  5221  5343  5415  5076  4761

# %%
import matplotlib.pyplot as plt
import numpy as np

# Transpose so years are on x-axis
df_plot = df.set_index("utbildningens inriktning").T

# Plot
df_plot.plot(kind="bar", figsize=(12, 6))


plt.title("Antal studerande per utbildningsinriktning (2020–2024)")
plt.xlabel("År")
plt.ylabel("Antal studerande")
plt.xticks(rotation=0)
plt.legend(title="Inriktning", bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# %%
df_plot.to_csv("data/Yrkeshogskolan_transformed.csv")

# %%
df_plot.plot(kind="bar", y="Data/It")
# Out:
# <Axes: >
