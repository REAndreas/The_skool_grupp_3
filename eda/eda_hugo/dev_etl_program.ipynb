# %%
import pandas as pd

# %%
rename_cols = {"Flera studiekommuner": "Flera kommuner", "Antal studiekommuner": "Antal kommuner"}

df_2020_4 = pd.read_excel("data/resultat-ansokningsomgang-2020.xlsx", sheet_name=4)
df_2020_5 = pd.read_excel("data/resultat-ansokningsomgang-2020.xlsx", sheet_name=5)

df_2021_4 = pd.read_excel("data/resultat-ansokningsomgang-2021.xlsx", sheet_name=4)
df_2021_5 = pd.read_excel("data/resultat-ansokningsomgang-2021.xlsx", sheet_name=5)

df_2022_4 = pd.read_excel("data/resultat-ansokningsomgang-2022.xlsx", sheet_name=4)
df_2022_5 = pd.read_excel("data/resultat-ansokningsomgang-2022.xlsx", sheet_name=5)

dataframes_2020_2022 = [df_2020_4, df_2020_5, df_2021_4, df_2021_5, df_2022_4, df_2022_5]

for df in dataframes_2020_2022:
    df.rename(columns=rename_cols, inplace=True)
    print(df.info())

cols_common_2020_2022 = set.intersection(*[set(df.columns) for df in [*dataframes_2020_2022]])
cols_common_2020_2022
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1482 entries, 0 to 1481
# Data columns (total 16 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Utbildningsområde                         1482 non-null   object
#  1   Utbildningsnamn                           1482 non-null   object
#  2   Län                                       1482 non-null   object
#  3   Kommun                                    1482 non-null   object
#  4   Flera kommuner                            1482 non-null   object
#  5   Antal kommuner                            1482 non-null   int64
#  6   Antal län                                 1482 non-null   int64
#  7   YH-poäng                                  1482 non-null   int64
#  8   Studieform                                1482 non-null   object
#  9   Studietakt %                              1482 non-null   int64
#  10  Utbildningsanordnare administrativ enhet  1482 non-null   object
#  11  Huvudmannatyp                             1482 non-null   object
#  12  Sökta utbildningsomgångar                 1482 non-null   int64
#  13  Beviljade utbildningsomgångar             1482 non-null   int64
#  14  Diarienummer                              1482 non-null   object
#  15  Beslut                                    1482 non-null   object
# dtypes: int64(6), object(10)
# memory usage: 185.4+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1903 entries, 0 to 1902
# Data columns (total 18 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Utbildningsområde                         1903 non-null   object
#  1   Utbildningsnamn                           1903 non-null   object
#  2   Län                                       1903 non-null   object
#  3   Kommun                                    1903 non-null   object
#  4   Flera kommuner                            1903 non-null   object
#  5   Antal kommuner                            1903 non-null   int64
#  6   Antal län                                 1903 non-null   int64
#  7   YH-poäng                                  1903 non-null   int64
#  8   Studieform                                1903 non-null   object
#  9   Studietakt %                              1903 non-null   int64
#  10  Utbildningsanordnare administrativ enhet  1903 non-null   object
#  11  Huvudmannatyp                             1903 non-null   object
#  12  Sökta platser per utbildningsomgång       1903 non-null   int64
#  13  Sökta platser totalt                      1903 non-null   int64
#  14  Beviljade platser per utbildningsomgång   1903 non-null   int64
#  15  Beviljade platser totalt                  1903 non-null   int64
#  16  Diarienummer                              1903 non-null   object
#  17  Beslut                                    1903 non-null   object
# dtypes: int64(8), object(10)
# memory usage: 267.7+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1238 entries, 0 to 1237
# Data columns (total 17 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Utbildningsområde                         1238 non-null   object
#  1   Utbildningsnamn                           1238 non-null   object
#  2   Län                                       1238 non-null   object
#  3   Kommun                                    1238 non-null   object
#  4   Flera kommuner                            1238 non-null   object
#  5   Antal kommuner                            1238 non-null   int64
#  6   Antal län                                 1238 non-null   int64
#  7   YH-poäng                                  1238 non-null   int64
#  8   Studieform                                1238 non-null   object
#  9   Studietakt %                              1238 non-null   int64
#  10  Typ av examen                             1238 non-null   object
#  11  Utbildningsanordnare administrativ enhet  1238 non-null   object
#  12  Huvudmannatyp                             1238 non-null   object
#  13  Sökta utbildningsomgångar                 1238 non-null   int64
#  14  Beviljade utbildningsomgångar             1238 non-null   int64
#  15  Diarienummer                              1238 non-null   object
#  16  Beslut                                    1238 non-null   object
# dtypes: int64(6), object(11)
# memory usage: 164.6+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1586 entries, 0 to 1585
# Data columns (total 23 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Utbildningsområde                         1586 non-null   object
#  1   Utbildningsnamn                           1586 non-null   object
#  2   Län                                       1586 non-null   object
#  3   Kommun                                    1586 non-null   object
#  4   Flera kommuner                            1586 non-null   object
#  5   Antal kommuner                            1586 non-null   int64
#  6   Antal län                                 1586 non-null   int64
#  7   YH-poäng                                  1586 non-null   int64
#  8   Studieform                                1586 non-null   object
#  9   Studietakt %                              1586 non-null   int64
#  10  Typ av examen                             1586 non-null   object
#  11  Utbildningsanordnare administrativ enhet  1586 non-null   object
#  12  Huvudmannatyp                             1586 non-null   object
#  13  Sökta platser per utbildningsomgång       1586 non-null   int64
#  14  Sökta platser totalt                      1586 non-null   int64
#  15  Beviljade platser utbildningsomgång 1     1586 non-null   float64
#  16  Beviljade platser utbildningsomgång 2     1586 non-null   object
#  17  Beviljade platser utbildningsomgång 3     1586 non-null   object
#  18  Beviljade platser utbildningsomgång 4     1586 non-null   object
#  19  Beviljade platser utbildningsomgång 5     1586 non-null   object
#  20  Beviljade platser totalt                  1586 non-null   float64
#  21  Diarienummer                              1586 non-null   object
#  22  Beslut                                    1586 non-null   object
# dtypes: float64(2), int64(6), object(15)
# memory usage: 285.1+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1207 entries, 0 to 1206
# Data columns (total 16 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Utbildningsområde                         1207 non-null   object
#  1   Utbildningsnamn                           1207 non-null   object
#  2   Beslut                                    1207 non-null   object
#  3   Diarienummer                              1207 non-null   object
#  4   Län                                       1207 non-null   object
#  5   Kommun                                    1207 non-null   object
#  6   Flera kommuner                            1207 non-null   object
#  7   Antal kommuner                            1207 non-null   int64
#  8   YH-poäng                                  1207 non-null   int64
#  9   Studieform                                1207 non-null   object
#  10  Studietakt %                              1207 non-null   int64
#  11  Typ av examen                             1207 non-null   object
#  12  Utbildningsanordnare administrativ enhet  1207 non-null   object
#  13  Huvudmannatyp                             1207 non-null   object
#  14  Sökta utbildningsomgångar                 1207 non-null   int64
#  15  Beviljade utbildningsomgångar             1207 non-null   int64
# dtypes: int64(5), object(11)
# memory usage: 151.0+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1621 entries, 0 to 1620
# Data columns (total 22 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Utbildningsområde                         1621 non-null   object
#  1   Utbildningsnamn                           1621 non-null   object
#  2   Beslut                                    1621 non-null   object
#  3   Diarienummer                              1621 non-null   object
#  4   Län                                       1621 non-null   object
#  5   Kommun                                    1621 non-null   object
#  6   Flera kommuner                            1621 non-null   object
#  7   Antal kommuner                            1621 non-null   int64
#  8   YH-poäng                                  1621 non-null   int64
#  9   Studieform                                1621 non-null   object
#  10  Studietakt %                              1621 non-null   int64
#  11  Typ av examen                             1621 non-null   object
#  12  Utbildningsanordnare administrativ enhet  1621 non-null   object
#  13  Huvudmannatyp                             1621 non-null   object
#  14  Sökta platser per utbildningsomgång       1621 non-null   int64
#  15  Sökta platser totalt                      1621 non-null   int64
#  16  Beviljade platser utbildningsomgång 1     1621 non-null   float64
#  17  Beviljade platser utbildningsomgång 2     1621 non-null   float64
#  18  Beviljade platser utbildningsomgång 3     1621 non-null   int64
#  19  Beviljade platser utbildningsomgång 4     1621 non-null   int64
#  20  Beviljade platser utbildningsomgång 5     1621 non-null   int64
#  21  Beviljade platser totalt                  1621 non-null   float64
# dtypes: float64(3), int64(8), object(11)
# memory usage: 278.7+ KB
# None
# {'Antal kommuner',
#  'Beslut',
#  'Diarienummer',
#  'Flera kommuner',
#  'Huvudmannatyp',
#  'Kommun',
#  'Län',
#  'Studieform',
#  'Studietakt %',
#  'Utbildningsanordnare administrativ enhet',
#  'Utbildningsnamn',
#  'Utbildningsområde',
#  'YH-poäng'}

# %%
df_2023_4 = pd.read_excel("data/resultat-ansokningsomgang-2023.xlsx", sheet_name=4, skiprows=5)
df_2023_5 = pd.read_excel("data/resultat-ansokningsomgang-2023.xlsx", sheet_name=5, skiprows=5)

df_2024_4 = pd.read_excel("data/resultat-ansokningsomgang-2024.xlsx", sheet_name=4, skiprows=5)
df_2024_5 = pd.read_excel("data/resultat-ansokningsomgang-2024.xlsx", sheet_name=5, skiprows=5)

dataframes_2023_2024 = [df_2023_4, df_2023_5, df_2024_4, df_2024_5]

for df in dataframes_2023_2024:
    # df.rename(columns=rename_cols, inplace=True)
    print(df.info())

cols_common_2023_2024 = set.intersection(*[set(df.columns) for df in [*dataframes_2023_2024]])
cols_common_2023_2024
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 28 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Utbildningsområde                         1258 non-null   object
#  1   SUN5 inriktning                           1258 non-null   object
#  2   SUN5 inriktning namn                      1258 non-null   object
#  3   Utbildningsnamn                           1258 non-null   object
#  4   Beslut                                    1258 non-null   object
#  5   Diarienummer                              1258 non-null   object
#  6   Flera kommuner                            1258 non-null   object
#  7   Antal kommuner                            1258 non-null   int64
#  8   Län                                       1258 non-null   object
#  9   Kommun                                    1258 non-null   object
#  10  YH-poäng                                  1258 non-null   int64
#  11  Studieform                                1258 non-null   object
#  12  Studietakt %                              1258 non-null   int64
#  13  Typ av examen                             1258 non-null   object
#  14  SeQF nivå                                 1242 non-null   float64
#  15  Smalt yrkesområde                         1258 non-null   object
#  16  Utbildningsanordnare administrativ enhet  1258 non-null   object
#  17  Huvudmannatyp                             1258 non-null   object
#  18  Sökta utbildningsomgångar                 1258 non-null   int64
#  19  Beviljade utbildningsomgångar             1258 non-null   int64
#  20  Sökta platser per utbildningsomgång       1258 non-null   int64
#  21  Sökta platser totalt                      1258 non-null   int64
#  22  Beviljade platser utbildningsomgång 1     1258 non-null   int64
#  23  Beviljade platser utbildningsomgång 2     1258 non-null   int64
#  24  Beviljade platser utbildningsomgång 3     1258 non-null   int64
#  25  Beviljade platser utbildningsomgång 4     1258 non-null   int64
#  26  Beviljade platser utbildningsomgång 5     1258 non-null   int64
#  27  Beviljade platser totalt                  1258 non-null   int64
# dtypes: float64(1), int64(13), object(14)
# memory usage: 275.3+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 642 entries, 0 to 641
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Utbildningsområde     642 non-null    object
#  1   SUN5 inriktning       642 non-null    object
#  2   SUN5 inriktning namn  642 non-null    object
#  3   Utbildningsnamn       642 non-null    object
#  4   Beslut                642 non-null    object
#  5   Diarienummer          642 non-null    object
#  6   Län                   642 non-null    object
#  7   Kommun                642 non-null    object
#  8   Antal kommuner        642 non-null    int64
# dtypes: int64(1), object(8)
# memory usage: 45.3+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1272 entries, 0 to 1271
# Data columns (total 28 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Utbildningsområde                         1272 non-null   object
#  1   SUN5 inriktning                           1272 non-null   object
#  2   SUN5 inriktning namn                      1272 non-null   object
#  3   Utbildningsnamn                           1272 non-null   object
#  4   Beslut                                    1272 non-null   object
#  5   Diarienummer                              1272 non-null   object
#  6   Flera kommuner                            1272 non-null   object
#  7   Antal kommuner                            1272 non-null   int64
#  8   Län                                       1272 non-null   object
#  9   Kommun                                    1272 non-null   object
#  10  YH-poäng                                  1272 non-null   int64
#  11  Studieform                                1272 non-null   object
#  12  Studietakt %                              1272 non-null   int64
#  13  Typ av examen                             1272 non-null   object
#  14  SeQF nivå                                 1252 non-null   float64
#  15  Smalt yrkesområde                         1272 non-null   object
#  16  Utbildningsanordnare administrativ enhet  1272 non-null   object
#  17  Huvudmannatyp                             1272 non-null   object
#  18  Sökta utbildningsomgångar                 1272 non-null   int64
#  19  Beviljade utbildningsomgångar             1272 non-null   int64
#  20  Sökta platser per utbildningsomgång       1272 non-null   int64
#  21  Sökta platser totalt                      1272 non-null   int64
#  22  Beviljade platser utbildningsomgång 1     1272 non-null   int64
#  23  Beviljade platser utbildningsomgång 2     1272 non-null   int64
#  24  Beviljade platser utbildningsomgång 3     1272 non-null   int64
#  25  Beviljade platser utbildningsomgång 4     1272 non-null   int64
#  26  Beviljade platser utbildningsomgång 5     1272 non-null   int64
#  27  Beviljade platser totalt                  1272 non-null   int64
# dtypes: float64(1), int64(13), object(14)
# memory usage: 278.4+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 842 entries, 0 to 841
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Utbildningsområde     842 non-null    object
#  1   SUN5 inriktning       842 non-null    object
#  2   SUN5 inriktning namn  842 non-null    object
#  3   Utbildningsnamn       842 non-null    object
#  4   Beslut                842 non-null    object
#  5   Diarienummer          842 non-null    object
#  6   Län                   842 non-null    object
#  7   Kommun                842 non-null    object
#  8   Antal kommuner        842 non-null    int64
# dtypes: int64(1), object(8)
# memory usage: 59.3+ KB
# None
# {'Antal kommuner',
#  'Beslut',
#  'Diarienummer',
#  'Kommun',
#  'Län',
#  'SUN5 inriktning',
#  'SUN5 inriktning namn',
#  'Utbildningsnamn',
#  'Utbildningsområde'}

# %%
set(cols_common_2020_2022).intersection(cols_common_2023_2024)
# Out:
# {'Antal kommuner',
#  'Beslut',
#  'Diarienummer',
#  'Kommun',
#  'Län',
#  'Utbildningsnamn',
#  'Utbildningsområde'}

# %%
pd.crosstab(df_2024_4["Flera kommuner"] == "Ja", df_2024_4["Län"] == "Flera kommuner")
# Out:
# Län             False  True
# Flera kommuner
# False             980      0
# True                0    292

# %%
def clean_strings(df):
    string_cols = df.select_dtypes("object").columns
    df.loc[:, string_cols] = df.loc[:, string_cols].apply(lambda x: x.str.strip().str.replace(r"\s+", " "))
    return df


def drop_suffix_cols(df, suffix="_y"):
    return df.drop(columns=[col for col in df.columns if col.endswith(suffix)])


def merge_and_clean_df_2020_22(df_4, df_5, suffix="_y", drop_suffix=False):
    df = pd.merge(
        left=df_4,
        right=df_5,
        on=["Diarienummer"],
        how="left",
        suffixes=(None, suffix),
    )

    df = df.assign(
        Län=df[f"Län{suffix}"],
        Kommun=df[f"Kommun{suffix}"],
    )

    if drop_suffix:
        df = drop_suffix_cols(df)

    return df


def merge_and_clean_df_2023_24(df_4, df_5, suffix="_y", drop_suffix=False):
    df = pd.merge(
        left=df_4.loc[df_4["Flera kommuner"] == "Ja"],
        # left=df_4,
        right=df_5,
        on=["Diarienummer"],
        how="left",
        suffixes=(None, suffix),
    )

    df = df.assign(
        Län=df[f"Län{suffix}"],
        Kommun=df[f"Kommun{suffix}"],
    )

    df = pd.concat([df, df_4.loc[df_4["Flera kommuner"] != "Ja"]])

    if drop_suffix:
        df = drop_suffix_cols(df)

    return df

# %%
rename_cols = {"Flera studiekommuner": "Flera kommuner", "Antal studiekommuner": "Antal kommuner"}

df_2020_4 = pd.read_excel("data/resultat-ansokningsomgang-2020.xlsx", sheet_name=4)
df_2020_5 = pd.read_excel("data/resultat-ansokningsomgang-2020.xlsx", sheet_name=5)

df_2021_4 = pd.read_excel("data/resultat-ansokningsomgang-2021.xlsx", sheet_name=4)
df_2021_5 = pd.read_excel("data/resultat-ansokningsomgang-2021.xlsx", sheet_name=5)

df_2022_4 = pd.read_excel("data/resultat-ansokningsomgang-2022.xlsx", sheet_name=4)
df_2022_5 = pd.read_excel("data/resultat-ansokningsomgang-2022.xlsx", sheet_name=5)

dataframes_2020_2022 = [df_2020_4, df_2020_5, df_2021_4, df_2021_5, df_2022_4, df_2022_5]
for df in dataframes_2020_2022:
    df.rename(columns=rename_cols, inplace=True)

df_2023_4 = pd.read_excel("data/resultat-ansokningsomgang-2023.xlsx", sheet_name=4, skiprows=5)
df_2023_5 = pd.read_excel("data/resultat-ansokningsomgang-2023.xlsx", sheet_name=5, skiprows=5)

df_2024_4 = pd.read_excel("data/resultat-ansokningsomgang-2024.xlsx", sheet_name=4, skiprows=5)
df_2024_5 = pd.read_excel("data/resultat-ansokningsomgang-2024.xlsx", sheet_name=5, skiprows=5)

# %%
df_2020_0 = merge_and_clean_df_2020_22(df_2020_4, df_2020_5)
df_2020_0["Ansökningsomgång"] = 2020
df_2021_0 = merge_and_clean_df_2020_22(df_2021_4, df_2021_5)
df_2021_0["Ansökningsomgång"] = 2021
df_2022_0 = merge_and_clean_df_2020_22(df_2022_4, df_2022_5)
df_2022_0["Ansökningsomgång"] = 2022

df_2023_0 = merge_and_clean_df_2023_24(df_2023_4, df_2023_5)
df_2023_0["Ansökningsomgång"] = 2023
df_2024_0 = merge_and_clean_df_2023_24(df_2024_4, df_2024_5)
df_2024_0["Ansökningsomgång"] = 2024

annual_dataframes = [df_2020_0, df_2021_0, df_2022_0, df_2023_0, df_2024_0]
df = pd.concat(annual_dataframes)

cols_common = set.intersection(*[set(df.columns) for df in [*annual_dataframes]])
df = df[list(cols_common)]

df = drop_suffix_cols(df)

# Convert 'Flera kommuner' to bool
df["Flera kommuner"] = df["Flera kommuner"].map({"Ja": True, "Nej": False})
if df["Flera kommuner"].isna().sum() > 0:
    raise ValueError(f"Found {df['Flera kommuner'].isna().sum()} NaN values in 'Flera kommuner'")

# Standardization of 'Beslut' and convert to bool
df["Beslut"] = df["Beslut"].map({"Beviljad": True, "Ej beviljad": False, "Avslag": False})
if df["Beslut"].isna().sum() > 0:
    raise ValueError(f"Found {df['Beslut'].isna().sum()} NaN values in 'Beslut'")

df = clean_strings(df)

df = df.sort_values(by=["Ansökningsomgång", "Diarienummer", "Län", "Kommun"]).reset_index(drop=True)

cols_order = [
    "Diarienummer",
    "Ansökningsomgång",
    "Beslut",
    "Utbildningsanordnare administrativ enhet",
    "Huvudmannatyp",
    "Utbildningsområde",
    "Utbildningsnamn",
    "YH-poäng",
    "Studieform",
    "Studietakt %",
    "Sökta utbildningsomgångar",
    "Beviljade utbildningsomgångar",
    "Sökta platser totalt",
    "Beviljade platser totalt",
    "Sökta platser per utbildningsomgång",
    "Län",
    "Kommun",
    "Antal kommuner",
    "Flera kommuner",
]

df = df[cols_order].rename(columns={"Utbildningsanordnare administrativ enhet": "Utbildningsanordnare"})

df.to_parquet("data/resultat-ansokningsomgang-2020-2024-beslut.parquet", index=False)

df
# Out:
#        Diarienummer  Ansökningsomgång  Beslut  \
# 0     MYH 2020/1698              2020    True
# 1     MYH 2020/1698              2020    True
# 2     MYH 2020/1698              2020    True
# 3     MYH 2020/1698              2020    True
# 4     MYH 2020/3237              2020    True
# ...             ...               ...     ...
# 8584  MYH 2024/4273              2024   False
# 8585  MYH 2024/4274              2024    True
# 8586  MYH 2024/4275              2024   False
# 8587  MYH 2024/4276              2024   False
# 8588  MYH 2024/4278              2024   False
#
#                                    Utbildningsanordnare Huvudmannatyp  \
# 0     Folkuniversitetet – Kursverksamheten vid Umeå ...        Privat
# 1     Folkuniversitetet – Kursverksamheten vid Umeå ...        Privat
# 2     Folkuniversitetet – Kursverksamheten vid Umeå ...        Privat
# 3     Folkuniversitetet – Kursverksamheten vid Umeå ...        Privat
# 4                                       Campus Nyköping        Kommun
# ...                                                 ...           ...
# 8584                                            AVIC AB        Privat
# 8585                         Umeå kommun - Dragonskolan        Kommun
# 8586                                            AVIC AB        Privat
# 8587                            IT-Högskolan Sverige AB        Privat
# 8588                          IT-Högskolan Stockholm AB        Privat
#
#                             Utbildningsområde  \
# 0              Samhällsbyggnad och byggteknik
# 1              Samhällsbyggnad och byggteknik
# 2              Samhällsbyggnad och byggteknik
# 3              Samhällsbyggnad och byggteknik
# 4     Hälso- och sjukvård samt socialt arbete
# ...                                       ...
# 8584                  Teknik och tillverkning
# 8585           Samhällsbyggnad och byggteknik
# 8586           Samhällsbyggnad och byggteknik
# 8587                                  Data/IT
# 8588                                  Data/IT
#
#                                         Utbildningsnamn  YH-poäng Studieform  \
# 0                                          VA-projektör       400     Bunden
# 1                                          VA-projektör       400     Bunden
# 2                                          VA-projektör       400     Bunden
# 3                                          VA-projektör       400     Bunden
# 4                                    Behandlingspedagog       400     Bunden
# ...                                                 ...       ...        ...
# 8584                                Automationstekniker       400    Distans
# 8585  Byggnadsvårdsingenjör - arbetsledning, renover...       415    Distans
# 8586    Optimering av hållbara energisystem med AI-stöd       400    Distans
# 8587                                    Python-Engineer       400     Bunden
# 8588                               .NET-Cloud developer       400     Bunden
#
#       Studietakt %  Sökta utbildningsomgångar  Beviljade utbildningsomgångar  \
# 0              100                          3                              3
# 1              100                          3                              3
# 2              100                          3                              3
# 3              100                          3                              3
# 4              100                          4                              3
# ...            ...                        ...                            ...
# 8584           100                          3                              0
# 8585           100                          2                              2
# 8586           100                          4                              0
# 8587           100                          3                              0
# 8588           100                          3                              0
#
#       Sökta platser totalt  Beviljade platser totalt  \
# 0                       30                      30.0
# 1                        9                       9.0
# 2                       15                      15.0
# 3                       21                      21.0
# 4                      140                     105.0
# ...                    ...                       ...
# 8584                    75                       0.0
# 8585                    40                      40.0
# 8586                   104                       0.0
# 8587                   105                       0.0
# 8588                   105                       0.0
#
#       Sökta platser per utbildningsomgång              Län     Kommun  \
# 0                                      10        Gävleborg      Gävle
# 1                                       3         Jämtland  Östersund
# 2                                       5     Västerbotten       Umeå
# 3                                       7   Västernorrland  Sundsvall
# 4                                      35     Södermanland   Nyköping
# ...                                   ...              ...        ...
# 8584                                   25        Stockholm  Stockholm
# 8585                                   20     Västerbotten       Umeå
# 8586                                   26        Stockholm  Stockholm
# 8587                                   35  Västra Götaland   Göteborg
# 8588                                   35        Stockholm  Stockholm
#
#       Antal kommuner  Flera kommuner
# 0                  4            True
# 1                  4            True
# 2                  4            True
# 3                  4            True
# 4                  1           False
# ...              ...             ...
# 8584               1           False
# 8585               1           False
# 8586               1           False
# 8587               1           False
# 8588               1           False
#
# [8589 rows x 19 columns]
