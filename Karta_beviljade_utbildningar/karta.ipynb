# %%
import pandas as pd
# Read the csv files for 2024
df= pd.read_csv("data/resultat-ansokningsomgang-2020-2024-beviljade.csv")
df
# Out:
#       Utbildningsområde                                    Utbildningsnamn  \
# 0               Data/IT                                   .NET Utvecklare
# 1               Data/IT                                    .NET-utvecklare
# 2               Data/IT                                    .NET-utvecklare
# 3               Data/IT                                Agil Javautvecklare
# 4               Data/IT                                 Agil projektledare
# ...                 ...                                                ...
# 2146  Transporttjänster                                          Lokförare
# 2147  Transporttjänster                                    Lokförare Malmö
# 2148  Transporttjänster                                Lokförare Stockholm
# 2149             Övrigt  Hantverkslärling - smala och traditionella han...
# 2150             Övrigt     Lärlingsutbildning inom traditionellt hantverk
#
#                   Län     Kommun  Antal kommuner  Flera kommuner  YH-poäng  \
# 0     Västra Götaland   Göteborg               1           False       400
# 1           Stockholm  Stockholm               1           False       400
# 2     Västra Götaland   Göteborg               1           False       400
# 3           Gävleborg      Gävle               1           False       400
# 4               Skåne      Malmö               1           False       225
# ...               ...        ...             ...             ...       ...
# 2146  Västra Götaland   Göteborg               1           False       220
# 2147            Skåne      Malmö               1           False       220
# 2148        Stockholm      Solna               1           False       220
# 2149          Dalarna    Leksand               1           False       500
# 2150        Stockholm  Stockholm               1           False       400
#
#                     Utbildningsanordnare  Ansökningsomgång   Diarienummer
# 0     Plushögskolan AB - Teknikhögskolan              2020  MYH 2020/4403
# 1              IT-Högskolan Stockholm AB              2020  MYH 2020/5766
# 2                IT-Högskolan Sverige AB              2020  MYH 2020/5764
# 3                            Edugrade AB              2020  MYH 2020/5827
# 4           IHM Business School AB Malmö              2020  MYH 2020/5354
# ...                                  ...               ...            ...
# 2146                      TCC Sverige AB              2024  MYH 2024/4150
# 2147              ProTrain Utbildning AB              2024  MYH 2024/3991
# 2148              ProTrain Utbildning AB              2024  MYH 2024/3996
# 2149    Stiftelsen Hantverk & Utbildning              2024  MYH 2024/3586
# 2150      Hantverksakademin i Sverige AB              2024  MYH 2024/3026
#
# [2151 rows x 10 columns]

# %%
df.head()
# Out:
#   Utbildningsområde      Utbildningsnamn              Län     Kommun  \
# 0           Data/IT     .NET Utvecklare   Västra Götaland   Göteborg
# 1           Data/IT      .NET-utvecklare        Stockholm  Stockholm
# 2           Data/IT      .NET-utvecklare  Västra Götaland   Göteborg
# 3           Data/IT  Agil Javautvecklare        Gävleborg      Gävle
# 4           Data/IT   Agil projektledare            Skåne      Malmö
#
#    Antal kommuner  Flera kommuner  YH-poäng  \
# 0               1           False       400
# 1               1           False       400
# 2               1           False       400
# 3               1           False       400
# 4               1           False       225
#
#                  Utbildningsanordnare  Ansökningsomgång   Diarienummer
# 0  Plushögskolan AB - Teknikhögskolan              2020  MYH 2020/4403
# 1           IT-Högskolan Stockholm AB              2020  MYH 2020/5766
# 2             IT-Högskolan Sverige AB              2020  MYH 2020/5764
# 3                         Edugrade AB              2020  MYH 2020/5827
# 4        IHM Business School AB Malmö              2020  MYH 2020/5354

# %%
df.columns
# Out:
# Index(['Utbildningsområde', 'Utbildningsnamn', 'Län', 'Kommun',
#        'Antal kommuner', 'Flera kommuner', 'YH-poäng', 'Utbildningsanordnare',
#        'Ansökningsomgång', 'Diarienummer'],
#       dtype='object')

# %%
df_2024_granted =df[df['Ansökningsomgång'] == 2024]

df_2024_granted
# Out:
#       Utbildningsområde                                    Utbildningsnamn  \
# 1807            Data/IT                 .NET-utvecklare med molninriktning
# 1808            Data/IT       Advanced Software Developer Embedded Systems
# 1809            Data/IT                                       AI Developer
# 1810            Data/IT                 Backend Developer inriktning Cloud
# 1811            Data/IT                                    Cloud Developer
# ...                 ...                                                ...
# 2146  Transporttjänster                                          Lokförare
# 2147  Transporttjänster                                    Lokförare Malmö
# 2148  Transporttjänster                                Lokförare Stockholm
# 2149             Övrigt  Hantverkslärling - smala och traditionella han...
# 2150             Övrigt     Lärlingsutbildning inom traditionellt hantverk
#
#                   Län       Kommun  Antal kommuner  Flera kommuner  YH-poäng  \
# 1807        Stockholm    Stockholm               1           False       400
# 1808  Västra Götaland  Trollhättan               1           False       400
# 1809        Stockholm    Stockholm               1           False       400
# 1810  Västra Götaland     Göteborg               1           False       400
# 1811  Västra Götaland      Mölndal               1           False       400
# ...               ...          ...             ...             ...       ...
# 2146  Västra Götaland     Göteborg               1           False       220
# 2147            Skåne        Malmö               1           False       220
# 2148        Stockholm        Solna               1           False       220
# 2149          Dalarna      Leksand               1           False       500
# 2150        Stockholm    Stockholm               1           False       400
#
#                   Utbildningsanordnare  Ansökningsomgång   Diarienummer
# 1807        JENSEN Education School AB              2024  MYH 2024/3043
# 1808                    YH Akademin AB              2024  MYH 2024/3281
# 1809        JENSEN Education School AB              2024  MYH 2024/3048
# 1810     Handelsakademin i Göteborg AB              2024  MYH 2024/3436
# 1811      Yrkeshögskola Campus Mölndal              2024  MYH 2024/4178
# ...                                ...               ...            ...
# 2146                    TCC Sverige AB              2024  MYH 2024/4150
# 2147            ProTrain Utbildning AB              2024  MYH 2024/3991
# 2148            ProTrain Utbildning AB              2024  MYH 2024/3996
# 2149  Stiftelsen Hantverk & Utbildning              2024  MYH 2024/3586
# 2150    Hantverksakademin i Sverige AB              2024  MYH 2024/3026
#
# [344 rows x 10 columns]

# %%
df_2024_granted.to_csv('filtered_data_2024.csv', index=False)
